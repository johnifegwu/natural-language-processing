# %% [markdown]
# # Build a spaCy Processing Pipeline

# %% [markdown]
# #Exercise #1:  Load Resources

# %%
#EXERCISE - Load spaCy Resources

# Install pandas
# %pip install pandas

# Install spaCy
# %pip install spacy

import pandas as pd
import spacy

#Download the English language model for spaCy
#Download the English model
spacy.cli.download("en_core_web_sm")

#Import the English language model
#Load the English model
nlp = spacy.load('en_core_web_sm')
# Out:
# Requirement already satisfied: pandas in e:\johni\python projects\natural language processing\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: spacy in e:\johni\python projects\natural language processing\.venv\lib\site-packages (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# When you execute nlp = spacy.load('en'), spaCy downloads and loads the pre-trained English language model into memory and assigns it to the variable nlp. This pre-trained model contains information about word vectors, part-of-speech tags, syntactic dependencies, and other linguistic features necessary for various NLP tasks.

# %% [markdown]
# ##spaCy Procesing Pipeline

# %% [markdown]
# In spaCy, the order of tasks in the processing pipeline generally follows a predefined sequence, although it's also customizable. By default, spaCy's processing pipeline includes the following components in the specified order:

# %% [markdown]
# ### Order of Tasks in the Processing Pipeline
#
# | Order | Name         | Definition |
# | :-----| :------ |: ---- |
# | 1     | Tokenization | Input text is split into individual tokens, such as words and punctuation marks. |
# | 2     | Stop Words    | Removes stop words from the text. |
# | 3     | POS Tagging   | Assigns grammatical labels (e.g., noun, verb, adjective) to each token in the text based on its syntactic role within the sentence. |
# | 4     | Dependency Parsing| Analyzes the grammatical structure of the text by determining the relationships |
# | 5     |Lemmatization | Reduces tokens to their base or root form (lemmas)  |
# | 6     |  Named Entity Recognition|  Identifies, categorizes persons, organizations, locations, dates, etc.|
# | 7     | Other Use Case Tasks| May be included in pipelne (Sentiment Analysis) |

# %% [markdown]
# # Exercise #2:  Build a Simple Processing Pipeline

# %%
#EXERCISE - Build a Simple Processing Pipeline

# Keep this
text = "A customer in New York City wants give a review."
doc = nlp(text)


#Processing Pipeline Order
#1. Tokenization
#2. Stop Words Removal
#3. POS Tagging
#4. Dependence Parsing
#5. Lemmatization
#6. Named Entity Recognition


#1. Tokenization
print("Tokenization:")
doc = nlp(text)
for token in doc:
    print(f"{token.text}\n")
    #Output: A customer in New York City wants give a review.

#2. Stop Words Removal
print("Filtered Tokens (without stop words):")
doc = nlp(text)
for token in doc:
    if not token.is_stop:
        print(f"{token.text}\n")
        #Output: A customer New York City wants give review.

#3. POS Tagging
print("Part-of-Speech Tagging (POS):")
doc = nlp(text)
for token in doc:
    print(token.text, token.pos_)
    #Output: A ADJ customer IN NOUN New York City NOUN wants VERB give DET a ADJ review NOUN
    print("\n")

#4. Dependence Parsing
print("Dependence Parsing:")
doc = nlp(text)
for chunk in doc.noun_chunks:
    print(chunk.text)
    #Output: A customer New York City wants give review
    print("\n")

#5. Lemmatization
print("Lemmatization:")
doc = nlp(text)
for token in doc:
    print(token.text, token.lemma_)
    #Output: A customer in New York City want give a review.
    print("\n")

#6. Named Entity Recognition
print("Named Entity Recognition (NER):")
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, ent.label_)
    #Output: New York City NOUN
    print("\n")


#Tokenization
#Stop Words Removal
#POS Tagging
#Dependence Parsing
#Lemmatization
#Named Entity Recognition
# Out:
# Tokenization:
# A
#
# customer
#
# in
#
# New
#
# York
#
# City
#
# wants
#
# give
#
# a
#
# review
#
# .
#
# Filtered Tokens (without stop words):
# customer
#
# New
#
# York
#
# City
#
# wants
#
# review
#
# .
#
# Part-of-Speech Tagging (POS):
# A DET
#
#
# customer NOUN
#
#
# in ADP
#
#
# New PROPN
#
#
# York PROPN
#
#
# City PROPN
#
#
# wants VERB
#
#
# give VERB
#
#
# a DET
#
#
# review NOUN
#
#
# . PUNCT
#
#
# Dependence Parsing:
# A customer
#
#
# New York City
#
#
# a review
#
#
# Lemmatization:
# A a
#
#
# customer customer
#
#
# in in
#
#
# New New
#
#
# York York
#
#
# City City
#
#
# wants want
#
#
# give give
#
#
# a a
#
#
# review review
#
#
# . .
#
#
# Named Entity Recognition (NER):
# New York City GPE

# %% [markdown]
# #Exercise #3: Build a Processing Pipeline with a File

# %%
# Run this cell

file_path = 'sentiment_examples.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    sentiment_texts = file.readlines()
    print(sentiment_texts)
# Out:
# ['"I love the new features of your product! It has greatly improved my productivity."\n', '"The customer support was exceptional in New York. They resolved my issue promptly and professionally."\n', '"The quality of your service exceeded my expectations in Prague. I\'m impressed!"\n', '"I\'m extremely satisfied with my purchase. The product works flawlessly."\n', '"The user interface is intuitive and easy to navigate. Kudos to your design team!"\n', '"I had a positive experience shopping on your website. The checkout process was smooth."\n', '"Your company values customer feedback, and it shows in the improvements you\'ve made."\n', '"The pricing is fair, and the value I get in return is fantastic."\n', '"I appreciate the personalized recommendations. It makes shopping more convenient."\n', '"The delivery was prompt, and the packaging was secure. Everything arrived in perfect condition."']

# %%
# EXERCISE - SCROLL DOWN TO THE "START HERE" SECTION BELOW.

# Initialize empty lists to store the results
token_lists = []
filtered_token_lists = []
pos_tag_lists = []
ner_lists = []

#-----------------------------------------------------------------------------
# START HERE

# Process each sentiment example using spaCy and store the results
for sentiment_text in sentiment_texts:
    doc = nlp(sentiment_text.strip())  # Strip any leading/trailing whitespace

    # Tokenization
    tokens = [token.text for token in doc]
    token_lists.append(tokens)

    # Stop Word Removal filter
    filtered_tokens = [token.text for token in doc if not token.is_stop]
    filtered_token_lists.append(filtered_tokens)


    # Part-of-Speech Tagging (POS tagging)
    pos_tags = [(token.text, token.pos_) for token in doc]
    pos_tag_lists.append(pos_tags)


    # Named Entity Recognition (NER)
    ents = [(ent.text, ent.label_) for ent in doc.ents]
    ner_lists.append(ents)

#-----------------------------------------------------------------------------
# Create a DataFrame to organize the results
results_df = pd.DataFrame({
    'Sentiment Example': sentiment_texts,
    'Tokens': token_lists,
    'Filtered Tokens': filtered_token_lists,
    'POS Tags': pos_tag_lists,
    'Named Entities': ner_lists
})

# Display the DataFrame
print(results_df)
# Out:
#                                    Sentiment Example  \
# 0  "I love the new features of your product! It h...
# 1  "The customer support was exceptional in New Y...
# 2  "The quality of your service exceeded my expec...
# 3  "I'm extremely satisfied with my purchase. The...
# 4  "The user interface is intuitive and easy to n...
# 5  "I had a positive experience shopping on your ...
# 6  "Your company values customer feedback, and it...
# 7  "The pricing is fair, and the value I get in r...
# 8  "I appreciate the personalized recommendations...
# 9  "The delivery was prompt, and the packaging wa...
#
#                                               Tokens  \
# 0  [", I, love, the, new, features, of, your, pro...
# 1  [", The, customer, support, was, exceptional, ...
# 2  [", The, quality, of, your, service, exceeded,...
# 3  [", I, 'm, extremely, satisfied, with, my, pur...
# 4  [", The, user, interface, is, intuitive, and, ...
# 5  [", I, had, a, positive, experience, shopping,...
# 6  [", Your, company, values, customer, feedback,...
# 7  [", The, pricing, is, fair, ,, and, the, value...
# 8  [", I, appreciate, the, personalized, recommen...
# 9  [", The, delivery, was, prompt, ,, and, the, p...
#
#                                      Filtered Tokens  \
# 0  [", love, new, features, product, !, greatly, ...
# 1  [", customer, support, exceptional, New, York,...
# 2  [", quality, service, exceeded, expectations, ...
# 3  [", extremely, satisfied, purchase, ., product...
# 4  [", user, interface, intuitive, easy, navigate...
# 5  [", positive, experience, shopping, website, ....
# 6  [", company, values, customer, feedback, ,, sh...
# 7  [", pricing, fair, ,, value, return, fantastic...
# 8  [", appreciate, personalized, recommendations,...
# 9  [", delivery, prompt, ,, packaging, secure, .,...
#
#                                             POS Tags     Named Entities
# 0  [(", PUNCT), (I, PRON), (love, VERB), (the, DE...                 []
# 1  [(", PUNCT), (The, DET), (customer, NOUN), (su...  [(New York, GPE)]
# 2  [(", PUNCT), (The, DET), (quality, NOUN), (of,...    [(Prague, GPE)]
# 3  [(", PUNCT), (I, PRON), ('m, AUX), (extremely,...                 []
# 4  [(", PUNCT), (The, DET), (user, NOUN), (interf...                 []
# 5  [(", PUNCT), (I, PRON), (had, VERB), (a, DET),...                 []
# 6  [(", PUNCT), (Your, PRON), (company, NOUN), (v...                 []
# 7  [(", PUNCT), (The, DET), (pricing, NOUN), (is,...                 []
# 8  [(", PUNCT), (I, PRON), (appreciate, VERB), (t...                 []
# 9  [(", PUNCT), (The, DET), (delivery, NOUN), (wa...                 []

# %% [markdown]
# #Exercise #4 (Optional): Exploratory Data Analysis

# %% [markdown]
# Perform Data Analysis: You can perform various data analysis tasks on the processed data. For example, you can calculate statistics, count occurrences, or visualize the data using plots and charts.
#
# Export Data to CSV or Excel: If you want to save the processed data for future use or analysis in other tools, you can export the DataFrame to a CSV or Excel file.

# %%
import os

# write as csv
file_path = 'processed_data.csv'

if os.path.exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_csv('processed_data.csv', index=False)

# write as xlsx
file_path = 'processed_data.xlsx'
if os.path.exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_excel('processed_data.xlsx', index=False)
# Out:
# The file processed_data.csv already exists.
# The file processed_data.xlsx already exists.

# %%
from utils import check_file_exists as file_exists

# write as csv
file_path = 'processed_data.csv'

if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_csv('processed_data.csv', index=False)

# write as xlsx
file_path = 'processed_data.xlsx'
if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_excel('processed_data.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[14], line 1
#
# ----> 1 from utils import check_file_exists as file_exists
#
#       3 # write as csv
#
#       4 file_path = 'processed_data.csv'
#
#
#
# ModuleNotFoundError: No module named 'utils'

# %%
from utils import check_file_exists as file_exists

# write as csv
file_path = 'processed_data.csv'

if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_csv('processed_data.csv', index=False)

# write as xlsx
file_path = 'processed_data.xlsx'
if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_excel('processed_data.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[14], line 1
#
# ----> 1 from utils import check_file_exists as file_exists
#
#       3 # write as csv
#
#       4 file_path = 'processed_data.csv'
#
#
#
# ModuleNotFoundError: No module named 'utils'

# %%
from utils import check_file_exists as file_exists

# write as csv
file_path = 'processed_data.csv'

if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_csv('processed_data.csv', index=False)

# write as xlsx
file_path = 'processed_data.xlsx'
if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_excel('processed_data.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[14], line 1
#
# ----> 1 from utils import check_file_exists as file_exists
#
#       3 # write as csv
#
#       4 file_path = 'processed_data.csv'
#
#
#
# ModuleNotFoundError: No module named 'utils'

# %%
from utils import check_file_exists as file_exists

# write as csv
file_path = 'processed_data.csv'

if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_csv('processed_data.csv', index=False)

# write as xlsx
file_path = 'processed_data.xlsx'
if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_excel('processed_data.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[14], line 1
#
# ----> 1 from utils import check_file_exists as file_exists
#
#       3 # write as csv
#
#       4 file_path = 'processed_data.csv'
#
#
#
# ModuleNotFoundError: No module named 'utils'

# %%
from utils import check_file_exists as file_exists

# write as csv
file_path = 'processed_data.csv'

if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_csv('processed_data.csv', index=False)

# write as xlsx
file_path = 'processed_data.xlsx'
if file_exists(file_path):
    print(f"The file {file_path} already exists.")
else:
    results_df.to_excel('processed_data.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[14], line 1
#
# ----> 1 from utils import check_file_exists as file_exists
#
#       3 # write as csv
#
#       4 file_path = 'processed_data.csv'
#
#
#
# ModuleNotFoundError: No module named 'utils'

# %%
processed_df = pd.read_csv('processed_data.csv', encoding='latin-1')

# %%
processed_df.head()
# Out:
#                                    Sentiment Example  \
# 0  "I love the new features of your product! It h...
# 1  "The customer support was exceptional in New Y...
# 2  "The quality of your service exceeded my expec...
# 3  "I'm extremely satisfied with my purchase. The...
# 4  "The user interface is intuitive and easy to n...
#
#                                               Tokens  \
# 0  ['"', 'I', 'love', 'the', 'new', 'features', '...
# 1  ['"', 'The', 'customer', 'support', 'was', 'ex...
# 2  ['"', 'The', 'quality', 'of', 'your', 'service...
# 3  ['"', 'I', "'m", 'extremely', 'satisfied', 'wi...
# 4  ['"', 'The', 'user', 'interface', 'is', 'intui...
#
#                                      Filtered Tokens  \
# 0  ['"', 'love', 'new', 'features', 'product', '!...
# 1  ['"', 'customer', 'support', 'exceptional', 'N...
# 2  ['"', 'quality', 'service', 'exceeded', 'expec...
# 3  ['"', 'extremely', 'satisfied', 'purchase', '....
# 4  ['"', 'user', 'interface', 'intuitive', 'easy'...
#
#                                             POS Tags         Named Entities
# 0  [('"', 'PUNCT'), ('I', 'PRON'), ('love', 'VERB...                     []
# 1  [('"', 'PUNCT'), ('The', 'DET'), ('customer', ...  [('New York', 'GPE')]
# 2  [('"', 'PUNCT'), ('The', 'DET'), ('quality', '...    [('Prague', 'GPE')]
# 3  [('"', 'PUNCT'), ('I', 'PRON'), ("'m", 'AUX'),...                     []
# 4  [('"', 'PUNCT'), ('The', 'DET'), ('user', 'NOU...                     []

# %% [markdown]
# Calculate the count of tokens for each sentiment.

# %%
# Install WordCloud
# %pip install wordcloud

# Now import WordCloud
from wordcloud import WordCloud

# get proccessed data from proccessed_data.csv
processed_data = pd.read_csv('processed_data.csv')

# Combine all tokens into a single text
all_tokens = ' '.join(processed_data['Tokens'])

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_tokens)

# install matplotlib
# %pip install matplotlib

# import matplotlib
import matplotlib.pyplot as plt

# Display the word cloud
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.title('Word Cloud of Tokens')
plt.show()
# Out:
# Requirement already satisfied: wordcloud in e:\johni\python projects\natural language processing\.venv\lib\site-packages (1.9.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.6.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: matplotlib in e:\johni\python projects\natural language processing\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\johni\python projects\natural language processing\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# Load the processed data from the CSV file
file_path = 'processed_data.csv'  # Update with the path to your processed data CSV file
processed_data = pd.read_csv(file_path)

# Calculate the count of tokens for each sentiment example
token_counts = processed_data['Tokens'].apply(lambda x: len(x.split()))

# Create a bar chart
plt.figure(figsize=(10, 6))  # Set the figure size
plt.barh(processed_data['Sentiment Example'], token_counts)  # Horizontal bar chart
plt.xlabel('Token Count')  # X-axis label
plt.ylabel('Sentiment Example')  # Y-axis label
plt.title('Token Count in Sentiment Examples')  # Chart title
plt.grid(axis='x')  # Show grid lines on the x-axis
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %% [markdown]
# Histogram of Token Lengths: Visualize the distribution of token lengths in the sentiment examples. This can give insights into the length of words used in the text.

# %%
# Load the processed data from the CSV file
file_path = 'processed_data.csv'  # Update with the path to your processed data CSV file
processed_data = pd.read_csv(file_path)

# Calculate token lengths for each sentiment example
processed_data['Token Length'] = processed_data['Tokens'].apply(lambda x: len(x.split()))

# Create a bar chart to visualize token lengths
plt.figure(figsize=(12, 8))
plt.bar(processed_data['Sentiment Example'], processed_data['Token Length'], color='skyblue')
plt.xlabel('Sentiment Example')
plt.ylabel('Token Length')
plt.title('Distribution of Token Lengths in Sentiment Examples')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Calculate token lengths
token_lengths = processed_data['Tokens'].apply(lambda x: len(x.split()))

# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(token_lengths, bins=20, edgecolor='black')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.title('Distribution of Token Lengths')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Word Cloud of Tokens: Create a word cloud to visualize the most common words in the sentiment examples. This can highlight frequently used words and themes.
